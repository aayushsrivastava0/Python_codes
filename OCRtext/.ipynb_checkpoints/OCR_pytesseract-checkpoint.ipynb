# %%
from PIL import Image
import pytesseract
import numpy as np
import re
import cv2


#cv2.imshow('image',image) # dipalying the image
#cv2.waitKey(0) 
#cv2.destroyAllWindows()

#text = pytesseract.image_to_string(image)
#print(text)

def ocr_core(img):
    text = pytesseract.image_to_string(img)
    return text

img= cv2.imread('invoice.jpg')  #reading the image
    
#PREPROCESSING THE IMAGE

def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

#image1=get_grayscale(image)

# noise removal
def remove_noise(image):
    return cv2.medianBlur(image,3)
 
#thresholding
def thresholding(image):
    return cv2.threshold(image, 100, 230, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

#dilation
def dilate(image):
    kernel = np.ones((2,2),np.uint8)
    return cv2.dilate(image, kernel, iterations = 1)
    
#erosion
def erode(image):
    kernel = np.ones((3,3),np.uint8)
    return cv2.erode(image, kernel, iterations = 1)

#opening - erosion followed by dilation
def opening(image):
    kernel = np.ones((1,1),np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

#skew correction
def deskew(image):
    coords = np.column_stack(np.where(image > 0))
    angle = cv2.minAreaRect(coords)[-1]
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated


#canny edge detection == NOT RECOMMENDED RESULTING IN ACCURACY DROP
#def canny(image):
#    return cv2.Canny(image, 100, 200)

img= get_grayscale(img)
img= thresholding(img)
img= remove_noise(img)
img=erode(img)
img=dilate(img)
img= opening(img)


#d = pytesseract.image_to_data(img, output_type=Output.DICT)
#n_boxes = len(d['level'])
#for i in range(n_boxes):

#    (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])    
#    img = cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 2)

#cv2.imshow('image',img)
#cv2.waitKey(0) 
#cv2.destroyAllWindows()

print(ocr_core(img))
# Out:
# Original Copy
# GSTIN : 0O9AAACB130501Z0
# TAX INVOICE
#
# BANSAL WIRE INDUSTRIES LIMITED (UNIT-III)
# Trusted Wire house Since 1938
# Unit-III Works: B-5 & B-€, SITE-II, LONI ROAD INDUSTRIAL AREA, MOHAN NAGAR, GHAZIABAD-201007 (UP)
# Tel.: 0120-2658290, 92 Fax : 0120-2658291 Website: www.bansalwire.com Email: bwil3@bansalwire.com
# Regd. Office: F-3, Main Road, Shastri Nayar, Delhi-110052 Phone:011-23651891
# CIN: Reeder Gin ne eee
#
# Invoice No. : BWIL/ASPL/0808 GRIRR No. : $3000317566 /29-01-2020
# Date Of Supply : 29-01-2020 Tiansport : Associated Road Carrier Ltd.
# P.O. No/Date : 1111029828 DT 27.01.2020 | Vehicle No. : TN29AT8168
#
# Payment Terms : 60 DAYS : Station : Madurai
#
# Place of Supply & State Code : Tamilnadu (33) \
#
# BILL TO: SHIP TO:
#
# TVS SRICHAKRA LTD. : TVS SRICHAKRA LTD.
#
# PERIJMAL PATTI ROAD |'PERUMAL PATTI ROAD
#
# MELUR TALUK MELUR TALUK
#
# MADURAI-625122 ' MADURAI-625122
#
# PAN : AAACTSSS7G PAN : AAACTSSS7G
#
# GSTIN : 33AAACTS557G1ZE ea 3 33AAACTS557G1ZE
#
# Material removed/dispatched from the premises oft the job worker M/s Aradhya Steel Pvt. Ltd., Sy. 154, P.B.
#
# Road, Halavarthy, Anagodu, Davangere, Karnataka as intimated to Dy. Commissioner GST, Ghaziabad (U.P.)
#
#
#
#
#
# ———
# S.N. Description of Goods HSN/SAC Gross Qty | Net Qty. !unit Price’ Amount(®)
# 1. 0.965MM TYRE BEAD WIRE 72173020 24243.000 - 19281.000 Kgs. 68.00 13,11,108.00
# 20 CAGES (40 SPOOLS) ' ;
# | | :
# i I
# > 18.00 % 2,35,999.44
# 4 oe Pa rast fuk. Less : Rounded OM (-) | 0.44
# oO 9.201.000 Kgs. Grand Tots! ¢ | 15,47,107.00
#
# * Sale @18%o= 13,11,108.00 IGST=2,35,999.44 Total Sale=13,11,108.00 IGST=235999.44
#
# Boer we . Ie: “
#
# Rupees Fifteen Lakh Forty Seven Thousand One Hundred Seven Only
#
# wee ee ee e —__
#
# styl
# Maternal sokc after Job Work against ASPL job work challan no. ]W/808 Datea ee AW
# 29.11.2020
#
#
#
# “QUR BANK DETAIL:- Canara Bank, Sadar fe Delhi-110006
#
# Account no :- 0271261004762, RTGS/IFSC:-CNRBO000271
# CHEQUE/DD/RTGS/NEFT in the name of “BANSAL WIRE INDUSTRIES LTD"
# Other Bank:- State Bank of India, Gautam Budh Nagar, Noida, U.P
# een No:-38807869701, RIGS/IFSC:-SBINOOU9E37-
#
# Terns Declaration: certified that the particulars given above are true and the amo:
# 41) Goods once solu will not be taken back or exchanged Indicated represented the price actually charged and that there is no flow o
# (2) Selle 9 20 resporsible for asty loss or damage of good additional consideration directly or indirectly from the buyer.
#
# iN trarsit. . ” —_—_—_
# (3) Bill Got pad by due date will attract 18% interest. For Bansal Wire Industries Limited - Unit III
#
# (4) Dispute, 1 ary, win be subject to Delhi Jundction.
# Authorised Signatory

# %%
#Fixing orientation
##
#Applying median blur
#image_blur=cv2.GaussianBlur(image2,(3,3),cv2.BORDER_DEFAULT)
#increaseing the size of our image
#image1=cv2.resize(image_blur, None, fx=2.0,fy=2.0,interpolation=cv2.INTER_CUBIC)

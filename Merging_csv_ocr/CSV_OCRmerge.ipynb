# %%
import pandas as pd
from glob import glob
final_file = sorted(glob('output*.csv'))
final_file
# Out:
# ['output1.csv', 'output2.csv']

# %%
# %%time 
merge = pd.concat((pd.read_csv(file) for file in final_file), ignore_index = True)
# Out:
# CPU times: user 7.89 ms, sys: 397 µs, total: 8.28 ms
# Wall time: 6.75 ms

# %%
merge
# Out:
#               BREADS & CEREALS          Portion size * per 100 grams (3.5 oz)  \
# 0          Bagel ( 1 average )          140 cals (45g)               310 cals
# 1           Biscuit digestives   86 cals (per biscuit)               480 cals
# 2                   Jaffa cake   48 cals (per biscuit)               370 cals
# 3    Bread white (thick slice)  96  cals (1 slice 40g)               240 cals
# 4      Bread wholemeal (thick)  88  cals (1 slice 40g)               220 cals
# ..                         ...                     ...                    ...
# 290                        NaN                     NaN                    NaN
# 291                        NaN                     NaN                    NaN
# 292                        NaN                     NaN                    NaN
# 293                        NaN                     NaN                    NaN
# 294                        NaN                     NaN                    NaN
#
#      Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6 Unnamed: 7  Unnamed: 0  \
# 0           NaN         NaN         NaN         NaN        NaN         NaN
# 1           NaN         NaN         NaN         NaN        NaN         NaN
# 2           NaN         NaN         NaN         NaN        NaN         NaN
# 3           NaN         NaN         NaN         NaN        NaN         NaN
# 4           NaN         NaN         NaN         NaN        NaN         NaN
# ..          ...         ...         ...         ...        ...         ...
# 290         NaN         NaN         NaN         NaN        NaN        59.0
# 291         NaN         NaN         NaN         NaN        NaN        60.0
# 292         NaN         NaN         NaN         NaN        NaN        61.0
# 293         NaN         NaN         NaN         NaN        NaN        62.0
# 294         NaN         NaN         NaN         NaN        NaN        63.0
#
#     Amount
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 290     15
# 291     10
# 292    309
# 293    726
# 294   1664
#
# [295 rows x 10 columns]

# %%
#creating  a combined CSV
merge.to_csv('merged.csv')
